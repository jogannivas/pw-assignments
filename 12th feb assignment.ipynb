# %% [raw]
# Q1/ What is exception in python? Write the difference between exception and syntax errors.
# Answer:-
# when a Python script encounters a situation that it cannot cope with, it raises an exception or  an exception is a Python object that represents an error.
#
#
# An Exception is an event that occurs during the program execution and disrupts the normal flow of the program's execution and errors mostly happen at compile-time.
#
# An error is an issue in a program that prevents the program from completing its task where  an exception is a condition that interrupts the normal flow of the program.
#
# Q2/ What happens when an exception is not handled?Explain with example.
# Answer:-
# If the exception is not handled by an except clause, the exception is re-raised after the finally clause has been executed.
#
# # initialize the amount variable
# age = 100
#
# # check that You are eligible to do that or not
#
# if(agg > 18)
# print("You are eligible to purchase book")
#
# Q3/ Which python statement are used to catch and handle exception ?Explain with an example.
# Answer:-
# The try and except block in Python is used to catch and handle exceptions.
# If an exception occurs during execution of the try clause, the exception may be handled by an except clause.
#
#
# def divide(x, y):
# 	try:
#
# 		result = x / y
# 		print("Yeah ! Your answer is :", result)
# 	except ZeroDivisionError:
# 		print("Sorry ! You are dividing by zero ")
#
# divide(0, 30)
# output//
# Yeah ! Your answer is : 0.0
#
# Q4/  Explain with example
# Try and else
# Finally
# raise
# Answer:-
# Try and else
# 	The try block lets you test a block of code for errors. The except block lets you handle the error. The else block lets you execute code when there is no error.
#
#
#
# def divide(x, y):
# 	try:
#
# 		result = x / y
# 	except ZeroDivisionError:
# 		print("Sorry ! You are dividing by zero ")
# 	else:
# 		print("Yeah ! Your answer is :", result)
#
#
# divide(3, 2)
# divide(3, 0)
#
# finally
# The finally keyword is used in try... except blocks. It defines a block of code to run when the try... except...else block is final. The finally block will be executed no matter if the try block raises an error or not.
#
#
# def divide(x, y):
# 	try:
#
# 		result = x / y
# 	except ZeroDivisionError:
# 		print("Sorry ! You are dividing by zero ")
# 	else:
# 		print("Yeah ! Your answer is :", result)
# 	finally:
#
# 		print('This is always executed')
#
#
# divide(3, 2)
# divide(3, 0)
#
# Raise
# The raise keyword is used to raise an exception. You can define what kind of error to raise, and the text to print to the user.
#
# class validage(Exception):
#     def __init__(self,msg):
#         self.msg=msg
# def validage(age):
#     if age<0:
#         raise validage ("Entered age is not velid")
#     elif age >200:
#         raise validage ("entered age is more high")
#     else:
#         print(" age is valid")
#
# Q4/ What is custom exception in python? Explain why do we need custom exception ?Explain with an example.
# Answer:-
#
# Custom exceptions provide you the flexibility to add attributes and methods that are not part of a standard python exception. These can store additional information, like an application-specific error code, or provide utility methods that can be used to handle or present the exception to a user.
# custom exceptions help users when the code follows the it's easier to ask for forgiveness than permission coding strategy.
#
#
#
# class validage(Exception):
#     def __init__(self,msg):
#         self.msg=msg
# def validage(age):
#     if age<0:
#         raise validage ("Entered age is not velid")
#     elif age >200:
#         raise validage ("entered age is more high")
#     else:
#         print(" age is valid")
# try:
#     age =int (input("enter your age "))
#     validage(age)
# except validage as e:
#     print (e)
# Q6/  Create a custom exception class and use this class to handle this exception.
# Answer:-
# class validage(Exception):
#     def __init__(self,msg):
#         self.msg=msg
# def validage(age):
#     if age<0:
#         raise validage ("Entered age is not velid")
#     elif age >200:
#         raise validage ("entered age is more high")
#     else:
#         print(" age is valid")
# try:
#     age =int (input("enter your age "))
#     validage(age)
# except validage as e:
#     print (e)
#
# output//
# TypeError                                 Traceback (most recent call last)
# Cell In [15], line 3
#       2     age =int (input("enter your age "))
# ----> 3     validage(age)
#       4 except validage as e:
#
# Cell In [13], line 5, in validage(age)
#       4 elif age >200:
# ----> 5     raise validage ("entered age is more high")
#       6 else:
#
# Cell In [13], line 2, in validage(age)
#       1 def validage(age):
# ----> 2     if age<0:
#       3         raise validage ("Entered age is not velid")
#
# TypeError: '<' not supported between instances of 'str' and 'int'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In [15], line 4
#       2     age =int (input("enter your age "))
#       3     validage(age)
# ----> 4 except validage as e:
#       5     print (e)
#
# TypeError: catching classes that do not inherit from BaseException is not allowed
