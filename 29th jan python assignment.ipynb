# %% [raw]
# Q1// who developed python programming language?
# ans:=
# Python was created by Guido van Rossum, and first released on February 20, 1991.
# Q2// which type of programming does python support?
# ans:=
# Python is an interpreted programming language, supporting object-oriented, structured, and functional programming.
#
#
# Q3// is python case sensitive with identifiers
# ans:-
# Yes, Python is a case-sensitive language, i.e., it treats uppercase and lowercase characters differently. This applies to identifiers too. You must avoid using the same name with different cases while naming identifiers.
# Q4//  what is the correct extension of python file?
# ans:-
#
# Python is a widely used programming or coding language used for different purposes. The extensions for Python files are - . py, . pyi, .
#
# Q5//   is python code compiled or interpreted?
# ans:-
#
#     Python is an interpreted language, which means the source code of a Python program is converted into bytecode that is then executed by the Python virtual machine.
#
# Q6// name a few blocks of code used to define in python language.
# ans:-
#   The following are blocks: a module, a function body, and a class definition. Each command typed interactively is a block. A script file (a file given as standard input to the interpreter or specified as a command line argument to the interpreter) is a code block.
# Q7//  character used to single line commentin python language.
# ans:-
# We can write a single-line comment by adding a single # character before any statement or line of code.
# Q8//  mentioned the function which can help us to find the verson of the python.
# ans:-
# We can also use the .python_version() method present in the platform module to print the version of the Python interpreter installed on the system.
# Q9//  python supports the creation of anonymous functions at runtime.
# ans:-
# Python supports the creation of anonymous functions  at runtime, using a construct called lambda.
# Q10//  what does pip stand for python?
# ans:-
# PIP is a package manager for Python packages.
# Q11// some built in function in python.
# ans:-
# iter()	Returns an iterator object
# int()	Returns an integer number
# input()	Allowing user input
# len()	Returns the length of an object
# list()	Returns a list
# print()	Prints to the standard output device
# range()	Returns a sequence of numbers, starting from 0 and increments by 1
#
# Q12//  what may be the maximum possible length of a identifier in python?
# ans :-
# An identifier can have a maximum length of 79 characters in Python.
# Q13//  what are the benefits of using python ?
# ans :-
# Python programming is a general-purpose skill used in almost all fields, including:
#
# Data science
# Scientific and mathematical computing
# Web development
# Finance and trading
# System automation and administration
# Computer graphics
# Q14//  how is memory managed in python?
# ans :-
# Memory in Python is managed by Python private heap space. All Python objects and data structures are located in a private heap. This private heap is taken care of by Python Interpreter itself, and a programmer doesn't have access to this private heap.
# Q15//
# ans:-
# First we nee to download python editor(pychamp,anaconda) from browser and instell it .
# The complete path of python.exe can be added by:
# :-Right-clicking This PC and going to Properties.
# :-Clicking on the Advanced system settings in the menu on the left.
# :-Clicking on the Environment Variables button o​n the bottom right.
# :-In the System variables section, selecting the Path variable and clicking on Edit.
# Q16//  Is indentation required in python?
# ans:-
# The indentation in Python is very important. Python uses indentation to indicate a block of code.
